# %% [markdown]
# # Some commands
# Enter key
# Shift + Enter
# Ctrl + enter
# Tab
# Shift + Tab
# Ctrl + S

# %%
# coming after using pycharm?
import os
print("Harshit")
os.getcwd() # press tab after os. , u will get suggestions # shift + tab --> another feature

# %%
"hi"
# jupyter is a very interactive tool, it prints hi without using the print statement. It will always show any result
# Out:
# 'hi'

# %%
"hi";
 # use semicolon if you dont want to print or show the output

# %%
# !mkdir this

# %%
# %lsmagic
# these are magic commands available in jupyter
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C41E-7627
#
#  Directory of C:\Users\Acer\Music\Python Data Science and Big Data tutorial with CWH
#
# 30-07-2021  21:50    <DIR>          .
# 30-07-2021  21:50    <DIR>          ..
# 30-07-2021  21:35    <DIR>          .ipynb_checkpoints
# 30-07-2021  21:47             1,942 Demo.ipynb
# 30-07-2021  21:50    <DIR>          this
#                1 File(s)          1,942 bytes
#                4 Dir(s)  20,938,625,024 bytes free

# %%
# %%html
# <h1>this is my place</h1>
# Out:
# <h1>this is my place</h1>

# %%
print("hi")
# Out:
# hi

# %%
# %matplotlib inline # it will run the matplotlib code here only
# Out:
# UsageError: unrecognized arguments: # it will run the matplotlib code

# %%
# !pip install matplotlib #--> it will run but not recommended to do it here

# %%
# read the jupyter notebook documentation if want to know more

# %%
# %time print("HARSHIT")
# Out:
# HARSHIT
# Wall time: 0 ns

# %% [markdown]
# It shows 0ns which is not much relevant as it dont show the exact data

# %% [markdown]
# If we want to know the exact time then use timeit magic method
#
#  magic methods --> provided by jupyter
#  modules
#  both are different

# %%
# %timeit print("HARSHIT")
# Out:
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# HARSHIT
# ...

# %% [markdown]
#  timeit method runs it 1000 times and calculate the average time
